# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading in the data
# - bullet

# %%
y = pd.read_feather("y_full.feather").drop('index', axis = 1)
x = pd.read_feather("X_full.feather").drop('index', axis = 1)

# %% [markdown]
# v_1 and V_inner should match

# %%
y
# Out:
#                  v_1           v_2           v_3           v_4           v_5  \
# 0       8.603849e+08  1.882901e+07  2.083296e+07  2.142437e+07  2.189659e+07
# 1       8.171245e+08  4.709196e+06  2.242958e+07  2.304173e+07  2.367058e+07
# 2       1.105810e+09  2.177831e+07  2.963174e+07  3.313080e+07  3.381658e+07
# 3       1.029141e+09  3.416763e+06  1.889603e+07  2.451080e+07  2.493680e+07
# 4       8.216514e+08  4.629587e+05  2.272563e+07  2.335383e+07  2.399940e+07
# ...              ...           ...           ...           ...           ...
# 174694  9.816786e+08  7.264299e+06  2.022876e+07  2.390584e+07  2.435769e+07
# 174695  8.864155e+08  2.457475e+07  2.965176e+07  3.091497e+07  3.185668e+07
# 174696  8.408668e+08  1.968020e+07  2.110692e+07  2.165204e+07  2.215765e+07
# 174697  1.052642e+09  2.583609e+07  2.680201e+07  2.748010e+07  2.797460e+07
# 174698  8.681552e+08  9.308743e+06  1.964906e+07  2.091644e+07  2.136762e+07
#
# ...

# %%
np.sum(y.v_1.isin(x.v_inner))
# Out:
# 174699

# %% [markdown]
# # Check parameter distibutions

# %% [markdown]
# ## X

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))

x.iloc[:, 0].plot(ax=axes[0], kind="hist", bins=50, edgecolor='black')
axes[0].spines["top"].set_visible(False)
axes[0].spines["right"].set_visible(False)
axes[0].set_title("Distribution of T_inner", loc="left", fontsize=15)

x.iloc[:, 1].plot(ax=axes[1], kind="hist", bins=50, edgecolor='black')
axes[1].spines["top"].set_visible(False)
axes[1].spines["right"].set_visible(False)
axes[1].set_title("Distribution of v_inner", loc="left", fontsize=15)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))

x.iloc[:, 2].plot(ax=axes[0], kind="hist", bins=50, edgecolor='black')
axes[0].spines["top"].set_visible(False)
axes[0].spines["right"].set_visible(False)
axes[0].set_title("Distribution of t_exp", loc="left", fontsize=15)

(-1*(x.iloc[:, 3])).plot(ax=axes[1], kind="hist", bins=50, edgecolor='black')
axes[1].spines["top"].set_visible(False)
axes[1].spines["right"].set_visible(False)
axes[1].set_title("Distribution of alpha", loc="left", fontsize=15)

plt.tight_layout()
plt.show()

# %%
import numpy as np

axes_array = x.iloc[:, 4:].plot(kind="hist", subplots=True, layout=(5, 2), sharex=False, bins=50, figsize=(15, 10), edgecolor='black')

for row_axes in axes_array:
    for ax in row_axes:
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

plt.suptitle("Distribution of abundances", fontsize=20, x=0.05, y=0.95, ha='left') 
plt.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()

# %% [markdown]
# ## y

# %%
np.log(y.iloc[:,1:]).plot(kind = "hist",  subplots=True, layout=(10, 8), sharex=False, bins=50, figsize=(20, 20), edgecolor='black');
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visual of the scaled distributions
# - alphas* -1
# - log transformation
# - standard scalar

# %% [markdown]
# ## preprocess

# %%
x
# Out:
#              T_inner       v_inner      t_exp     alpha         c         o  \
# 0        9948.519776  8.603849e+08  11.952723 -7.971268  0.027072  0.009264
# 1        8356.551873  8.171245e+08   8.914340 -7.066185  0.000365  0.000090
# 2       11367.804933  9.298924e+08  10.254887 -8.285835  0.022356  0.085046
# 3       10462.684666  1.105810e+09   9.477628 -9.190108  0.095159  0.221062
# 4        8769.282693  1.029141e+09  10.683997 -9.528657  0.001032  0.000010
# ...              ...           ...        ...       ...       ...       ...
# 233924   9639.527919  9.346672e+08  10.872497 -8.457079  0.001692  0.000682
# 233925  10471.876458  8.297304e+08   8.493559 -8.243021  0.000481  0.005067
# 233926  13954.654515  8.885075e+08   8.392082 -5.739827  0.090224  0.133843
# 233927  10574.030154  1.280205e+09   9.136035 -8.709988  0.058381  0.337208
# 233928   9127.464156  1.572995e+09  10.537543 -6.286938  0.114631  0.258813
#
# ...

# %%
x["alpha"] = x.alpha *-1
X_log = np.log(x + 1e-6)
y_log = np.log(y  + 1e-6)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_log, y_log, random_state=22, train_size=.8)

# %%
scalar_X_tr = StandardScaler()
scalar_y_tr = StandardScaler()
scalar_X_tes = StandardScaler()
scalar_y_tes = StandardScaler()


scalar_X_tr.fit(X_train)
scalar_y_tr.fit(y_train)
scalar_X_tes.fit(X_test)
scalar_y_tes.fit(y_test)
# Out:
# StandardScaler()

# %%
X_scaled_train = scalar_X_tr.transform(X_train)
y_scaled_train = scalar_y_tr.transform(y_train)
X_scaled_test = scalar_X_tes.transform(X_test)
y_scaled_test = scalar_y_tes.transform(y_test)

# %%
X_scaled_train_df = pd.DataFrame(X_scaled_train, columns=X_train.columns)
y_scaled_train_df = pd.DataFrame(y_scaled_train, columns=y_train.columns)

# %% [markdown]
# ## Plot the distributions
# ### X

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))

X_scaled_train_df.iloc[:, 0].plot(ax=axes[0], kind="hist", bins=50, edgecolor='black')
axes[0].spines["top"].set_visible(False)
axes[0].spines["right"].set_visible(False)
axes[0].set_title("Distribution of T_inner", loc="left", fontsize=15)

X_scaled_train_df.iloc[:, 1].plot(ax=axes[1], kind="hist", bins=50, edgecolor='black')
axes[1].spines["top"].set_visible(False)
axes[1].spines["right"].set_visible(False)
axes[1].set_title("Distribution of v_inner", loc="left", fontsize=15)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))

X_scaled_train_df.iloc[:, 2].plot(ax=axes[0], kind="hist", bins=50, edgecolor='black')
axes[0].spines["top"].set_visible(False)
axes[0].spines["right"].set_visible(False)
axes[0].set_title("Distribution of t_exp", loc="left", fontsize=15)

X_scaled_train_df.iloc[:, 3].plot(ax=axes[1], kind="hist", bins=50, edgecolor='black')
axes[1].spines["top"].set_visible(False)
axes[1].spines["right"].set_visible(False)
axes[1].set_title("Distribution of alpha", loc="left", fontsize=15)

plt.tight_layout()
plt.show()

# %%
import numpy as np

axes_array = X_scaled_train_df.iloc[:, 4:].plot(kind="hist", subplots=True, layout=(5, 2), sharex=False, bins=50, figsize=(15, 10), edgecolor='black')

for row_axes in axes_array:
    for ax in row_axes:
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

plt.suptitle("Distribution of log abundances", fontsize=20, x=0.05, y=0.95, ha='left') 
plt.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()

# %% [markdown]
# ### y

# %%
y_scaled_train_df.iloc[:,1:].plot(kind = "hist",  subplots=True, layout=(10, 8), sharex=False, bins=50, figsize=(20, 20), edgecolor='black');
plt.tight_layout()
plt.show()
